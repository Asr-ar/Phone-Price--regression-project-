# %% [markdown]
# # Phone Price Regression

# %% [markdown]
# ### Minimum Viable Product

# %% [markdown]
# After scraping the data from 91mobiles.com using Selenium and BeautifulSoup, the data reached 2658 rows and 108 columns.

# %% [markdown]
# Before moving on to building a model, we calculated the correlation between some of the columns with each other and with the target of the regression (price) as seen in the figure below.

# %% [markdown]
# ![corr_heatmap.png](attachment:corr_heatmap.png)
